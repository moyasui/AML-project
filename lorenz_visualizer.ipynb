# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plot_utils

# %%
lorenz_df = pd.read_csv('lorenz.csv', header=0, names=['t', 'x', 'y', 'z', 'particle'])
lorenz_df
# Out:
#              t          x         y          z  particle
# 0     0.000000  11.685804  2.770249  11.924933         0
# 1     0.010013  10.794248  4.641039  11.931012         0
# 2     0.020025  10.178927  6.355903  12.126127         0
# 3     0.030038   9.796625  7.936780  12.473641         0
# 4     0.040050   9.610640  9.405884  12.954580         0
# ...        ...        ...       ...        ...       ...
# 7995  7.959950   9.918674  7.589692  31.743747         9
# 7996  7.969962   9.685776  7.173130  31.642767         9
# 7997  7.979975   9.434511  6.777061  31.482725         9
# 7998  7.989987   9.168766  6.406600  31.268533         9
# 7999  8.000000   8.892550  6.065844  31.005731         9
#
# [8000 rows x 5 columns]

# %%
filename = 'lorenz_visualizer'

# Plot the Lorenz attractor second particle
fig = plt.figure(figsize=(18, 10))
ax = fig.add_subplot(projection='3d')

traj_1 = lorenz_df[lorenz_df['particle'] == 0]
traj_2 = lorenz_df[lorenz_df['particle'] == 7]

traj_1_initial_condition = traj_1.iloc[0]
traj_2_initial_condition = traj_2.iloc[0]


ax.plot(traj_1['x'], traj_1['y'], traj_1['z'], label='IC 1' )
ax.plot(traj_2['x'], traj_2['y'], traj_2['z'], label='IC 2' )

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

#ax.set_title('Lorenz Attractor')
ax.legend()
# remove the numbers from the axes
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_zticklabels([])

# Make x , y and z labels closer to the axes (default is 5.0)
ax.xaxis.labelpad = -10
ax.yaxis.labelpad = -10
ax.zaxis.labelpad = -10

plt.subplots_adjust(left=0.01, right=0.9, top=0.9, bottom=0.4) 

plot_utils.save(filename)

plt.show()
